# %% [markdown]
# <a href="https://colab.research.google.com/github/soumilijn-tech/AIML-LAB/blob/main/LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 3: Checking Routes Between Cities Using DFS
# Problem Statement:
# A small road network connects several cities. Write a Python program using DFS that:
# 1. Checks whether a route exists between two given cities.
# 2. Finds all separate groups of cities that are connected to each other but not to any
# other group (these are called connected components).

# %%
# Problem 3: Checking Routes Between Cities Using DFS

graph = {
    "Kolkata": ["Delhi", "Patna"],
    "Delhi": ["Kolkata", "Jaipur"],
    "Patna": ["Kolkata"],
    "Jaipur": ["Delhi"],
    "Mumbai": ["Pune"],
    "Pune": ["Mumbai"],
    "Chennai": []
}


# 1. Check whether a route exists between two cities
def route_exists(graph, start, destination):
    visited = set()

    def dfs(city):
        if city == destination:
            return True

        visited.add(city)

        for neighbour in graph[city]:
            if neighbour not in visited:
                if dfs(neighbour):
                    return True

        return False

    return dfs(start)


# 2. Find connected components
def connected_components(graph):
    visited = set()
    components = []

    def dfs(city, component):
        visited.add(city)
        component.append(city)

        for neighbour in graph[city]:
            if neighbour not in visited:
                dfs(neighbour, component)

    for city in graph:
        if city not in visited:
            component = []
            dfs(city, component)
            components.append(component)

    return components


# Input city names
start = input("Enter starting city: ")
destination = input("Enter destination city: ")

# Check route
if start not in graph or destination not in graph:
    print("City not found!")
elif route_exists(graph, start, destination):
    print("Route exists between", start, "and", destination)
else:
    print("No route exists between", start, "and", destination)


# Display connected components
print("\nConnected Components:")

components = connected_components(graph)

for i, component in enumerate(components, 1):
    print("Component", i, ":", component)
# Out:
# Enter starting city: Kolkata
# Enter destination city: Jaipur
# Route exists between Kolkata and Jaipur
#
# Connected Components:
# Component 1 : ['Kolkata', 'Delhi', 'Jaipur', 'Patna']
# Component 2 : ['Mumbai', 'Pune']
# Component 3 : ['Chennai']
